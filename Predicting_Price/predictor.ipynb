# %% [markdown]
# Install Necessery Libraries

# %%
# !pip install numpy pandas matplotlib seaborn scikit-learn
# Out:
# /usr/bin/pip:6: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import load_entry_point
# ...

# %% [markdown]
# Import scikit-learn and pandas for data manipulation and machine learning tasks.

# %%
from sklearn.datasets import fetch_california_housing
import pandas as pd

data = fetch_california_housing()

# %%
print(data)
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#           37.88      , -122.23      ],
#        [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#           37.86      , -122.22      ],
#        [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#           37.85      , -122.24      ],
#        ...,
#        [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#           39.43      , -121.22      ],
#        [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#           39.43      , -121.32      ],
#        [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
# ...

# %% [markdown]
# Make abstarct data to table

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
print(df)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %% [markdown]
# Make column named "Target"

# %%
df['Target'] = data.target

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Target
# 0    -122.23   4.526
# 1    -122.22   3.585
# 2    -122.24   3.521
# 3    -122.25   3.413
# 4    -122.25   3.422

# %%
df['Price'] = df['Target'] * 100000  # Convert target to price in dollars

# %% [markdown]
# Add Column Named "Year" equals 2025

# %%
df['Year'] = 2025

# %%
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Target     Price  Year
# 0    -122.23   4.526  452600.0  2025
# 1    -122.22   3.585  358500.0  2025
# 2    -122.24   3.521  352100.0  2025
# 3    -122.25   3.413  341300.0  2025
# 4    -122.25   3.422  342200.0  2025

# %% [markdown]
# import numpy for math and print value for year, every 2 rows the year add 1

# %%
import numpy as np

df['year'] = 2020 + (np.arange(len(df)) // 2)

# %%
df.head(30)
# Out:
#     MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0   8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1   8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2   7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3   5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4   3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5   4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# 6   3.6591      52.0  4.931907   0.951362      1094.0  2.128405     37.84
# 7   3.1200      52.0  4.797527   1.061824      1157.0  1.788253     37.84
# 8   2.0804      42.0  4.294118   1.117647      1206.0  2.026891     37.84
# 9   3.6912      52.0  4.970588   0.990196      1551.0  2.172269     37.84
# 10  3.2031      52.0  5.477612   1.079602       910.0  2.263682     37.85
# 11  3.2705      52.0  4.772480   1.024523      1504.0  2.049046     37.85
# ...

# %% [markdown]
# print shape of table

# %%
print(df.shape)
# Out:
# (20640, 12)

# %% [markdown]
# Print Table info

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   MedInc      20640 non-null  float64
#  1   HouseAge    20640 non-null  float64
#  2   AveRooms    20640 non-null  float64
#  3   AveBedrms   20640 non-null  float64
#  4   Population  20640 non-null  float64
#  5   AveOccup    20640 non-null  float64
#  6   Latitude    20640 non-null  float64
#  7   Longitude   20640 non-null  float64
#  8   Target      20640 non-null  float64
#  9   Price       20640 non-null  float64
#  10  Year        20640 non-null  int64
#  11  year        20640 non-null  int64
# dtypes: float64(10), int64(2)
# memory usage: 1.9 MB
# None

# %% [markdown]
# print table description

# %%
print(df.describe())
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude        Target          Price  \
# count  20640.000000  20640.000000  20640.000000  20640.000000   20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558  206855.816909
# ...

# %% [markdown]
# Visualize data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df, x_vars=['MedInc', 'HouseAge', 'AveRooms', 'AveOccup'], y_vars='Price', height=5, aspect=0.7)
plt.show()

# %%
sns.pairplot(df[['MedInc', 'HouseAge', 'AveRooms', 'AveOccup', 'Price']])
plt.show()

# %% [markdown]
# Pisahkan Fitur dan Target + Normalisasi

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x = df.drop('Target', axis=1)
y = df['Target']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# Training Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = LinearRegression()
model.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test_scaled)
print(y_pred)
# Out:
# [0.477   0.458   5.00001 ... 5.00001 0.723   1.515  ]

# %%
print("MSE : ", mean_squared_error(y_test, y_pred))
print("R2score : ", r2_score(y_test, y_pred))
# Out:
# MSE :  3.126986326365658e-30
# R2score :  1.0

# %% [markdown]
# Data Visualization

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual price")
plt.ylabel("Predicted Price")
plt.title("Actual VS Predicted")
plt.show()
